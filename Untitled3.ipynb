# %% [markdown]
# <a href="https://colab.research.google.com/github/Pasn2/NeuronNetworks/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
def f(x):
  return 3*x-1

x = np.arange(-2,2,0.1)
print(x)
y = np.array([f(_) for _ in x])
print(y)
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1,input_shape=(1,))
])
model.summary()
model.compile(
    loss="mse",
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
)
model.fit(x,y,epochs=100)
preds = model.predict(x)
print(y)
print(preds.flatten())
# Out:
# [-2.00000000e+00 -1.90000000e+00 -1.80000000e+00 -1.70000000e+00
#  -1.60000000e+00 -1.50000000e+00 -1.40000000e+00 -1.30000000e+00
#  -1.20000000e+00 -1.10000000e+00 -1.00000000e+00 -9.00000000e-01
#  -8.00000000e-01 -7.00000000e-01 -6.00000000e-01 -5.00000000e-01
#  -4.00000000e-01 -3.00000000e-01 -2.00000000e-01 -1.00000000e-01
#   1.77635684e-15  1.00000000e-01  2.00000000e-01  3.00000000e-01
#   4.00000000e-01  5.00000000e-01  6.00000000e-01  7.00000000e-01
#   8.00000000e-01  9.00000000e-01  1.00000000e+00  1.10000000e+00
#   1.20000000e+00  1.30000000e+00  1.40000000e+00  1.50000000e+00
#   1.60000000e+00  1.70000000e+00  1.80000000e+00  1.90000000e+00]
# [-7.  -6.7 -6.4 -6.1 -5.8 -5.5 -5.2 -4.9 -4.6 -4.3 -4.  -3.7 -3.4 -3.1
#  -2.8 -2.5 -2.2 -1.9 -1.6 -1.3 -1.  -0.7 -0.4 -0.1  0.2  0.5  0.8  1.1
#   1.4  1.7  2.   2.3  2.6  2.9  3.2  3.5  3.8  4.1  4.4  4.7]
# Model: "sequential_7"
# _________________________________________________________________
# ...
