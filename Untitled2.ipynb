# %% [markdown]
# <a href="https://colab.research.google.com/github/Pasn2/NeuronNetworks/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images = train_images / 255.0

test_images = test_images / 255.0
model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10)

])

model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=keras.optimizers.Adamax(),
    metrics=["accuracy"],
)
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

predictions = probability_model.predict(test_images)
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')


model.fit(train_images, train_labels, epochs=10,verbose = 2)
model.evaluate(train_images,verbose=2)
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
# Out:
# 2.9.2
# 313/313 [==============================] - 1s 3ms/step
# Epoch 1/10
# 1875/1875 - 6s - loss: 0.5484 - accuracy: 0.8120 - 6s/epoch - 3ms/step
# Epoch 2/10
# 1875/1875 - 5s - loss: 0.4182 - accuracy: 0.8539 - 5s/epoch - 3ms/step
# Epoch 3/10
# 1875/1875 - 5s - loss: 0.3833 - accuracy: 0.8650 - 5s/epoch - 3ms/step
# Epoch 4/10
# 1875/1875 - 5s - loss: 0.3598 - accuracy: 0.8723 - 5s/epoch - 3ms/step
# Epoch 5/10
# 1875/1875 - 5s - loss: 0.3414 - accuracy: 0.8784 - 5s/epoch - 3ms/step
# Epoch 6/10
# 1875/1875 - 5s - loss: 0.3275 - accuracy: 0.8828 - 5s/epoch - 3ms/step
# Epoch 7/10
# 1875/1875 - 5s - loss: 0.3163 - accuracy: 0.8865 - 5s/epoch - 3ms/step
# Epoch 8/10
# 1875/1875 - 5s - loss: 0.3038 - accuracy: 0.8892 - 5s/epoch - 3ms/step
# Epoch 9/10
# 1875/1875 - 6s - loss: 0.2958 - accuracy: 0.8935 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1875/1875 - 6s - loss: 0.2872 - accuracy: 0.8956 - 6s/epoch - 3ms/step
# ...
